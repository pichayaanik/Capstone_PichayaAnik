# %% [markdown]
# <a href="https://colab.research.google.com/github/pichayaanik/Capstone_PichayaAnik/blob/main/BERTopic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING: bertopic 0.12.0 does not provide the extra 'visualization'
# ...

# %%
import pandas as pd
from bertopic import BERTopic
from bertopic.backend import languages
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import DictVectorizer

# %%
! gdown 1QB-hJGlFCw8dfcQQbNYyXUAwu-AMdw9B
! gdown 1cE3xyicYkb_4SJKNYbQtQ5msmfbmIZ-g
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1QB-hJGlFCw8dfcQQbNYyXUAwu-AMdw9B
# To: /content/เศรษฐกิจ_processed.json
# 100% 144M/144M [00:00<00:00, 154MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1cE3xyicYkb_4SJKNYbQtQ5msmfbmIZ-g
# To: /content/economy_processed.json
# 100% 134M/134M [00:00<00:00, 213MB/s]

# %%
econ_b = pd.read_json('/content/เศรษฐกิจ_processed.json')
econ_m = pd.read_json('/content/economy_processed.json')

# %%
econ_b.columns
# Out:
# Index(['ID', 'date', 'category', 'title', 'description', 'article', 'url',
#        'title_count', 'title_tokenize', 'description_count',
#        'description_tokenize', 'article_count', 'article_tokenize'],
#       dtype='object')

# %%
model = BERTopic(language='thai')

# %%
topic_b, probabilities_b = model.fit_transform(econ_b['article'])
# Out:
# Downloading:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
model.get_topic_freq().head()
# Out:
#    Topic  Count
# 0     -1   1731
# 1      0    280
# 2      1    262
# 3      2    202
# 4      3    146

# %%
for i in range(4):
  print(f'Topic {i+1}')
  print(model.get_topic(i))
# Out:
# Topic 1
# [('ยดเพ', 0.9725902440280929), ('รายละเอ', 0.9266486026315565), ('มเต', 0.7102932790517161), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05)]
# Topic 2
# [('ำม', 0.058737202806952195), ('นด', 0.03727733782349356), ('ราคาน', 0.030133925290797562), ('บต', 0.02899828791247382), ('ฐฯ', 0.025805238369401302), ('นเบนซ', 0.02454960338166741), ('านบาร', 0.02454344552533569), ('ปร', 0.024262101111660165), ('ไบ', 0.0235737044146702), ('หล', 0.021370162401978764)]
# Topic 3
# [('งงาน', 0.018400224802389627), ('เมกะว', 0.01729826041843837), ('ตต', 0.016923030958189898), ('ไฟฟ', 0.016422501887313444), ('าไฟฟ', 0.011677456715045645), ('กฟผ', 0.011180389157302961), ('ตไฟฟ', 0.011062802210418757), ('กกพ', 0.010489593833324352), ('อไฟฟ', 0.010006720634553976), ('พล', 0.009487520882656107)]
# Topic 4
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cv = CountVectorizer(token_pattern="\b[A-zก-๙][A-z\.\-ก-๙]*\b")

# %%
econ_b.head()
# Out:
#        ID                date  category  \
# 0  859827 2020-01-01 11:15:00  เศรษฐกิจ
# 1  859831 2020-01-01 12:00:00  เศรษฐกิจ
# 2  859943 2020-01-02 07:00:00  เศรษฐกิจ
# 3  860014 2020-01-01 04:00:00  เศรษฐกิจ
# 4  860028 2020-01-02 08:00:00  เศรษฐกิจ
#
#                                                title  \
# 0  BIG STORY : นักเศรษฐศาสตร์คาดการณ์เศรษฐกิจไทย ...
# 1  ลึกแต่ไม่ลับ : ปิดหลักสูตร Digital Transformat...
# 2   ทำความรู้จัก 'BCG Economy' โมเดลใหม่ เศรษฐกิจไทย
# 3  AUTO TIMES : วัดช่วงชก Mitsubishi Xpander VS S...
# 4  'สมคิด' เร่งเครื่องลงทุนอีอีซี นัด สกพอ.ถกแนวท...
#
#                                          description  \
# 0  ห้องข่าวเศรษฐกิจ | 1 ม.ค. 63 "รู้ทัน ล้วงลึกทุ...
# 1  ห้องข่าวเศรษฐกิจ | 1 ม.ค. 63 "รู้ทัน ล้วงลึกทุ...
# 2  ตามไปทำความรู้จักคำศัพท์ใหม่แห่งปี "BCG Econom...
# 3  ห้องข่าวเศรษฐกิจ | 1 ม.ค. 63 "รู้ทัน ล้วงลึกทุ...
# 4  "สมคิด" นัดถก สกพอ. 6 ม.ค.นี้ วางแนวทางขับเคลื...
#
#                                              article  \
# ...

# %% [markdown]
# #Model 2: Bag-of-words

# %%
# Finction to store n_word in dict
def featurize(token_list):
    token_list=token_list
    features = {}
    for token in token_list:
        features[token]=1
    return features

# %%
econ_b_bow = econ_b['article_tokenize'].apply(featurize)
econ_m_bow = econ_m['article_tokenize'].apply(featurize)

# %%
econ_b_bow.shape, econ_m_bow.shape
# Out:
# ((6801,), (5884,))

# %%
vectorizer_1 = DictVectorizer(sparse=True)
econ_b_vec = vectorizer_1.fit_transform(econ_b_bow)

vectorizer_2 = DictVectorizer(sparse=True)
econ_m_vec = vectorizer_2.fit_transform(econ_m_bow)

# %%
econ_b_vec, econ_m_vec
# Out:
# (<6801x35157 sparse matrix of type '<class 'numpy.float64'>'
#  	with 844532 stored elements in Compressed Sparse Row format>,
#  <5884x40835 sparse matrix of type '<class 'numpy.float64'>'
#  	with 891436 stored elements in Compressed Sparse Row format>)

# %%
model_2 = BERTopic(language='thai')
topic_b_2, probabilities_b_2 = model.fit_transform(econ_b_vec)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-817c1d0d518f> in <module>
#       1 model_2 = BERTopic(language='thai')
# ----> 2 topic_b_2, probabilities_b_2 = model.fit_transform(econ_b_vec)
#
# /usr/local/lib/python3.7/dist-packages/bertopic/_bertopic.py in fit_transform(self, documents, embeddings, y)
#     320         ```
#     321         """
# --> 322         check_documents_type(documents)
#     323         check_embeddings_shape(embeddings, documents)
#     324
#
# /usr/local/lib/python3.7/dist-packages/bertopic/_utils.py in check_documents_type(documents)
#      34     if isinstance(documents, Iterable) and not isinstance(documents, str):
#      35         if not any([isinstance(doc, str) for doc in documents]):
# ---> 36             raise TypeError("Make sure that the iterable only contains strings.")
#      37
#      38     else:
#
# ...

# %% [markdown]
# #Multilingual BERTopic

# %%
model3 = BERTopic(language='multilingual', 
                  embedding_model='distiluse-base-multilingual-cased-v2')

# %%
topic_b, probabilities_b = model3.fit_transform(econ_b['article'])

# %%
model3.get_topic_freq().head()
# Out:
#    Topic  Count
# 0     -1   1723
# 1      0    281
# 2      1    152
# 3      2    143
# 4      3    138

# %%
for i in range(4):
  print(f'Topic {i+1}')
  print(model3.get_topic(i))
# Out:
# Topic 1
# [('ยดเพ', 0.520674924980165), ('รายละเอ', 0.4961306197973671), ('มเต', 0.3859526709026598), ('การทางอ', 0.04396794267162289), ('กทรอน', 0.03747501000541962), ('เล', 0.02706293001544298), ('ยนภาษ', 0.025931970602842417), ('กส', 0.024852374144463913), ('าเพ', 0.02425315303509748), ('บภาษ', 0.02091929630532927)]
# Topic 2
# [('ำม', 0.061464936693348), ('นด', 0.04157478377531246), ('บต', 0.03342549791490312), ('ราคาน', 0.033302058378277356), ('ฐฯ', 0.03298772416566885), ('านบาร', 0.03043575398973448), ('นเบนซ', 0.028870985870763755), ('ปร', 0.027967330993973537), ('ไบ', 0.02687640240867529), ('หล', 0.024555614368877415)]
# Topic 3
# [('บร', 0.01510324235984021), ('จำก', 0.010667013865287393), ('ปตท', 0.010046654300697245), ('รก', 0.008579097675583168), ('ตต', 0.008496236841476195), ('เมกะว', 0.008183474121275413), ('มหาชน', 0.008133508769147443), ('ทฯ', 0.007446393707041857), ('ประธานเจ', 0.006441546584293236), ('เพาเวอร', 0.006386639740675989)]
# Topic 4
# ...

# %%
model3.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Just Try T_T

# %%
# Finction to store n_word in dict
def featurize(token_list):
    token_list=token_list
    features = {}
    for token in token_list:
        features[token]=1
    return features

# %%
econ_b_bow = econ_b['article_tokenize'].apply(featurize)
econ_m_bow = econ_m['article_tokenize'].apply(featurize)

# %%
vectorizer_1 = DictVectorizer(sparse=True)
econ_b_vec = vectorizer_1.fit_transform(econ_b_bow)

vectorizer_2 = DictVectorizer(sparse=True)
econ_m_vec = vectorizer_2.fit_transform(econ_m_bow)

# %%
econ_b_vec, econ_m_vec
# Out:
# (<6801x35157 sparse matrix of type '<class 'numpy.float64'>'
#  	with 844532 stored elements in Compressed Sparse Row format>,
#  <5884x40835 sparse matrix of type '<class 'numpy.float64'>'
#  	with 891436 stored elements in Compressed Sparse Row format>)

# %%
model4 = BERTopic(
    vectorizer_model=vectorizer_1,
    language='multilingual',
    calculate_probabilities=True,
    verbose=True
)

# %%
type(econ_b['article'].tolist())
# Out:
# list

# %%
X = econ_b['article']

# %%
topics, probs = model4.fit_transform(econ_m_vec)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-c5a8f6680450> in <module>
# ----> 1 topics, probs = model4.fit_transform(econ_m_vec)
#
# /usr/local/lib/python3.7/dist-packages/bertopic/_bertopic.py in fit_transform(self, documents, embeddings, y)
#     320         ```
#     321         """
# --> 322         check_documents_type(documents)
#     323         check_embeddings_shape(embeddings, documents)
#     324
#
# /usr/local/lib/python3.7/dist-packages/bertopic/_utils.py in check_documents_type(documents)
#      34     if isinstance(documents, Iterable) and not isinstance(documents, str):
#      35         if not any([isinstance(doc, str) for doc in documents]):
# ---> 36             raise TypeError("Make sure that the iterable only contains strings.")
#      37
#      38     else:
#
# TypeError: Make sure that the iterable only contains strings.

# %%
for i in range(5):
  print(f'{topics[i]}: {econ_b['article'][i]}')
# Out:
#   File "<ipython-input-26-bc6ce8a4a1bd>", line 2
#     print(f'{topics[i]}: {econ_b['article'][i]}')
#                                         ^
# SyntaxError: invalid syntax

# %%
# See top words in each topics
freq = model4.get_topic_info()
freq.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-074052fe9aee> in <module>
#       1 # See top words in each topics
# ----> 2 freq = model4.get_topic_info()
#       3 freq.head(10)
#
# /usr/local/lib/python3.7/dist-packages/bertopic/_bertopic.py in get_topic_info(self, topic)
#    1116
#    1117         info = pd.DataFrame(self.topic_sizes_.items(), columns=["Topic", "Count"]).sort_values("Topic")
# -> 1118         info["Name"] = info.Topic.map(self.topic_labels_)
#    1119
#    1120         if self.custom_labels_ is not None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
# ...

# %%
model4.visualize_topics()

# %%
model4.visualize_hierarchy()

# %%
model4.visualize_barchart()

# %%
# Install pythainlp library
# !pip install pythainlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.6 MB 7.6 MB/s
# ...

# %%
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import DictVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic import BERTopic
from pythainlp.tokenize import sent_tokenize, word_tokenize
from pythainlp.corpus import thai_stopwords


# Step 1 - Extract embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Step 2 - Reduce dimensionality
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine')

# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(min_cluster_size=15, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# Step 4 - Tokenize topics
vectorizer_model = DictVectorizer(stop_words="english")

# Step 5 - Create topic representation
ctfidf_model = ClassTfidfTransformer()

# All steps together
topic_model = BERTopic(
  embedding_model=embedding_model,    # Step 1 - Extract embeddings
  umap_model=umap_model,              # Step 2 - Reduce dimensionality
  hdbscan_model=hdbscan_model,        # Step 3 - Cluster reduced embeddings
  vectorizer_model=vectorizer_model,  # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model,          # Step 5 - Extract topic words
  diversity=0.5                       # Step 6 - Diversify topic words
)
